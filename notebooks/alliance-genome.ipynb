# %% [markdown]
# # Alliance Genome

# %%
# Environment Setup

# %%
import requests
from concurrent.futures import ThreadPoolExecutor
import json
import os
import pandas as pd
import numpy as np
import gzip
import io
from tqdm import tqdm

# %%
# Setting up data directories
tmp_data = os.path.join('./resources/tmp_data')
processed_data = os.path.join('./resources/processed_data')

# %% [markdown]
# Utility Functions

# %%
def scrape_page(url, page, limit):
    """
    Scrape a single page of records from the API.

    Args:
        url (str): The URL of the API endpoint.
        page (int): The page number to scrape.
        limit (int): The number of records per page.

    Returns:
        list: A list of records from the specified page.
    """
    params = {'page': page, 'limit': limit}
    response = requests.get(url, params=params)
    data = response.json()
    return data['results']

def scrape_all_records(url, limit=20, max_workers=10):
    """
    Scrape all records from the API.

    Args:
        url (str): The URL of the API endpoint.
        limit (int, optional): The number of records per page. Defaults to 20.
        max_workers (int, optional): The maximum number of concurrent requests. Defaults to 10.

    Returns:
        list: A list of all records from the API.
    """
    response = requests.get(url, params={'page': 1, 'limit': limit})
    data = response.json()
    total_pages = -(-data['total'] // limit)  # ceiling division

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(scrape_page, url, page, limit) for page in range(1, total_pages + 1)]
        all_records = [record for future in futures for record in future.result()]

    return all_records

# %%
def download_gzipped_json(uri):
    # Send a GET request to the URI
    response = requests.get(uri)

    # Check if the response was successful
    if response.status_code != 200:
        raise Exception(f"Failed to download file from {uri}")

    # Create a BytesIO object to hold the gzipped data
    gzipped_data = io.BytesIO(response.content)

    # Create a GzipFile object to decompress the data
    with gzip.GzipFile(fileobj=gzipped_data, mode='rb') as f:
        # Read the decompressed data into a string
        json_data = f.read().decode('utf-8')

    # Parse the JSON data into a Python object
    data = json.loads(json_data)

    return data

# %%
from enum import Enum, auto
import requests
import os
import json
from biobox_analytics.utils import download_gzipped_json, oxo_mapping
import io
import pandas as pd
from tqdm import tqdm

class AllianceDownloads(Enum):

    DISEASE_HUMAN = "https://fms.alliancegenome.org/download/DISEASE-ALLIANCE-JSON_HUMAN.json.gz"
    DISEASE_MOUSE = "https://fms.alliancegenome.org/download/DISEASE-ALLIANCE-JSON_MGI.json.gz"


class AllianceGenomeAdapter:

    def __init__(self):
        self._api = "https://www.alliancegenome.org/api/"
        self._disease_gene_associations = []
        self._prepare_mappers()
        self._download_disease_associations()

    def _prepare_mappers(self):

        
        human = pd.read_table("https://www.alliancegenome.org/api/geneMap/ensembl?species=NCBITaxon:9606", sep="\t")

        mouse = pd.read_table("https://www.alliancegenome.org/api/geneMap/ensembl?species=NCBITaxon:10090", sep="\t")

        self._gene_map = pd.concat([human, mouse])


    def _download_disease_associations(self):
        human_results = download_gzipped_json(AllianceDownloads.DISEASE_HUMAN.value)
        DISEASE_IDS = list(set([x.get('DOID') for x in human_results['data']]))

        # self._doid_mapping = oxo_mapping(DISEASE_IDS, ["EFO", "MONDO"])
        with open(os.path.join('./resources/mappings', 'doid_efo.mapping.json'), 'r') as f:
            
            self._doid_mapping = json.load(f)

        for _id in tqdm(DISEASE_IDS, desc="Collecting DiseaseGene Annotations"):
 
            try:
                harmonized_disease_id = self._doid_mapping.get(_id)[0]
            except:
                continue
            
            records = scrape_all_records(f"https://www.alliancegenome.org/api/disease/{_id}/genes?filter.species=Homo sapiens")
            associations = []
            for anno in records:
                association = self._format_disease_gene_annotation(anno, harmonized_disease_id)
                if association is not None:
                    associations.append(association)
            self._disease_gene_associations.extend(associations)

    def _hgnc2ensembl(self, hgnc):
        subset = self._gene_map[self._gene_map['Gene ID'] == hgnc]
        return subset['Ensembl ID'].values[0]
    
    def _format_disease_gene_annotation(self, anno, disease_id, fmt="edge"):

        relation_str = anno.get('generatedRelationString').replace('_', ' ')
        disease_qualifiers = anno.get('diseaseQualifiers', [])

        if len(disease_qualifiers) > 1:
            print(anno)
            raise Exception("Disease Qualifiers should not be more than one in length")
            
        if len(disease_qualifiers) == 1:
            disease_qualifier_str = disease_qualifiers[0].replace('_', ' ')
            relation_str = f'{relation_str} {disease_qualifier_str}'

        uuid = anno.get("uniqueId")

        references = anno.get('pubmedPubModIDs')
        evidenceCodes = anno.get('evidenceCodes', [])
        evidence = [x.get('abbreviation') for x in evidenceCodes]
        

        try:
            gene_hgnc = anno['subject']['modEntityId']
            ensembl_id = self._hgnc2ensembl(gene_hgnc)
        except:
            return

        output = {
            'from': {
                'uuid': ensembl_id
            },
            'to': {
                'uuid': disease_id
            },
            'label': relation_str,
            'properties': {
                'uuid': uuid,
                'references': references,
                'evidence': evidence,
                'citation_authority': 'Alliance of Genome Resources'
            }
        }
        return output
        

    
    # def get_nodes(self):
    #     """
    #     Returns a generator of node tuples for node types specified in the
    #     adapter constructor.
    #     """
    #     print("Generating Nodes")

    #     for da in self._disease_gene_associations:

# %%
adapter = AllianceGenomeAdapter()
# Out:
# Collecting DiseaseGene Annotations: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6127/6127 [46:03<00:00,  2.22it/s]

# %%
len(adapter._disease_gene_associations)
# Out:
# 234908

# %%
adapter._disease_gene_associations[100]
# Out:
# {'from': {'uuid': 'ENSG00000156170'},
#  'to': {'uuid': 'MONDO:0009723'},
#  'label': 'is implicated via orthology',
#  'properties': {'uuid': 'wBCpG48BJgBeDSVnk52w',
#   'references': ['MGI:6194238'],
#   'evidence': ['IEA'],
#   'citation_authority': 'Alliance of Genome Resources'}}

# %%
with gzip.open(os.path.join('./resources/processed_data', 'alliance_disease_gene_edge.jsonl.gz'), 'wt') as f:
    for n in tqdm(adapter._disease_gene_associations):
        f.write(json.dumps(n) + '\n')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 234908/234908 [00:03<00:00, 74724.49it/s]

# %%
rel_labels = list(set([x.get('label') for x in adapter._disease_gene_associations]))
relationships = {
    x: {'from': 'Gene', 'to': 'Disease'} for x in rel_labels
}

alliance_gene_disease_associations_metadata = {
  "_meta": {
    "version": "0.1.0",
    "date_updated": "2024-05-20",
    "maintainer": "BioBox Analytics"
  },
  "key": "alliance_disease_gene",
  "name": "Alliance - Disease Gene Assocations",
  "description": "A consortium of 7 model organism databases (MODs) and the Gene Ontology (GO) Consortium whose goal is to provide an integrated view of their data to all biologists, clinicians and other interested parties. This data package contains edges between Genes and Diseases. It will require you to have loaded in EFO and MONDO ontologies.",
  "source": [
    {
      "uri": "https://www.alliancegenome.org/downloads",
      "type": "doc"
    },
    {
      "uri": "https://fms.alliancegenome.org/download/DISEASE-ALLIANCE-JSON_HUMAN.json.gz",
      "type": "data",
      "version": "7.1.0"
    }
  ],
  "concepts": {},
  "relationships": relationships
}

# %%
with open('./resources/processed_data/alliance_disease_gene_metadata.json', 'w') as outfile:
    json.dump(alliance_gene_disease_associations_metadata, outfile)

# %% [markdown]
# # Scratchpad

# %%
hmd_human_phenotype.head()
# Out:
#          0       1        2            3  \
# 0     A1BG       1     A1bg  MGI:2152878
# 1     A1CF   29974     A1cf  MGI:1917115
# 2      A2M       2      A2m  MGI:2449119
# 3  A3GALT2  127550  A3galt2  MGI:2685279
# 4   A4GALT   53947   A4galt  MGI:3512453
#
#                                                    4   5
# 0                                                NaN NaN
# 1  MP:0005367, MP:0005369, MP:0005370, MP:0005376... NaN
# 2                                                NaN NaN
# 3                                                NaN NaN
# 4                 MP:0005376, MP:0005386, MP:0010768 NaN

# %%
def download_tab_delimited_data(url, col_names):
    """Downloads tab-delimited data from a URL, skipping header lines and empty lines.

    Args:
        url: The URL of the tab-delimited file.

    Returns:
        A pandas DataFrame containing the data.
    """

    response = requests.get(url)
    response.raise_for_status()  # Raise an exception if the request failed

    # Filter out header lines and empty lines
    data_lines = [line for line in response.text.splitlines() 
                  if not line.startswith('#')]

    # Create a file-like object from the data

    data_io = io.StringIO('\n'.join(data_lines)) 

    # Read the data into a DataFrame, specifying the delimiter and quoting
    df = pd.read_table(data_io, sep='\t', names=col_names, header=None, skip_blank_lines=True, on_bad_lines='skip')

    return df

# %% [markdown]
# # MGI: Alleles and Genotypes

# %% [markdown]
# 2 Alleles -> 1 Genotype - model of -> Disease

# %%
mgi_disease_mouse_model = download_tab_delimited_data(
    "https://www.informatics.jax.org/downloads/reports/MGI_DiseaseMouseModel.rpt",
    ['do_term', 'DOID', 'negated', 'allele_pairs', 'strain', 'allele_symbol',
     'allele_mgi_id', 'totalNumAlleleReferences', 'repo_id', 'mouse_genotype_rr_id', 'mouse_gene_symbol', 'mouse_gene_id', 'repo_id_gene'])

# %%
mgi_disease_mouse_model.head()
# Out:
#                                              do_term          DOID negated  \
# 0  17-beta hydroxysteroid dehydrogenase 3 deficiency  DOID:0112248     NaN
# 1                 2-aminoadipic 2-oxoadipic aciduria  DOID:0111453     NaN
# 2                 3-methylglutaconic aciduria type 3  DOID:0110004     NaN
# 3  3-methylglutaconic aciduria with deafness, enc...  DOID:0110001     NaN
# 4                           46 XX gonadal dysgenesis    DOID:14450     NaN
#
#                           allele_pairs  \
# 0  Hsd17b3<tm1.2Mpo>/Hsd17b3<tm1.2Mpo>
# 1        Dhtkd1<em1Hpr>/Dhtkd1<em1Hpr>
# 2            Opa3<m1Votr>/Opa3<m1Votr>
# 3    Serac1<em1Bcgen>/Serac1<em1Bcgen>
# 4                Fancl<gcd>/Fancl<gcd>
#
#                                              strain      allele_symbol  \
# 0  involves: 129S6/SvEvTac * C57BL/6N * C57BL/6NCrl  Hsd17b3<tm1.2Mpo>
# 1                        involves: C57BL/6N * FVB/N     Dhtkd1<em1Hpr>
# 2                       involves: C3H * C57BL/6JCrl       Opa3<m1Votr>
# 3                         C57BL/6N-Serac1<em1Bcgen>   Serac1<em1Bcgen>
# 4                        involves: C57BL/6J * CBA/J         Fancl<gcd>
#
#   allele_mgi_id  totalNumAlleleReferences repo_id mouse_genotype_rr_id  \
# 0   MGI:6508689                       1.0     NaN     RRID:MGI:6508693
# 1   MGI:6268324                       1.0     NaN     RRID:MGI:6268326
# 2   MGI:5312669                       5.0     NaN     RRID:MGI:5312681
# 3   MGI:7316653                       1.0     NaN     RRID:MGI:7316678
# 4   MGI:1861640                       5.0     NaN     RRID:MGI:2660751
#
#   mouse_gene_symbol mouse_gene_id  \
# 0           Hsd17b3    MGI:107177
# 1            Dhtkd1   MGI:2445096
# 2              Opa3   MGI:2686271
# 3            Serac1   MGI:2447813
# 4             Fancl   MGI:1914280
#
#                                         repo_id_gene
# 0  EuMMCR:12655|EuMMCR:3397|EuMMCR:3398|MMRRC:069...
# 1  NM-KI-00005|MMRRC:042792-MU|MMRRC:045216-MU|MM...
# 2  EuMMCR:25483|MMRRC:067719-MU|MMRRC:041675-MU|M...
# 3  CMMR:CMMR:ADPW|NM-KO-2100721|MMRRC:069450-MU|M...
# 4  EuMMCR:9783|EuMMCR:9782|MMRRC:044564-MU|MMRRC:...

# %% [markdown]
# Gather all the alleles as nodes first.

# %%
mgi_phenotypic_allele = download_tab_delimited_data('https://www.informatics.jax.org/downloads/reports/MGI_PhenotypicAllele.rpt',
                                                   ['mgi_allele_id', 'allele_symbol', 'allele_name', 'allele_type', 'allele_attribute', 'PMID', 'mgi_marker_id','marker_symbol', 'marker_refseq_id', 'marker_ensembl_id', 'mp_id', 'synonyms', 'marker_name'])

# %%
mgi_phenotypic_allele.head()
# Out:
#   mgi_allele_id                      allele_symbol  \
# 0   MGI:5603349     0610010K14Rik<tm1.1(KOMP)Vlcg>
# 1   MGI:4452997       0610010K14Rik<tm1(KOMP)Vlcg>
# 2   MGI:7425474      0610040J01Rik<em1(IMPC)Ccpcz>
# 3   MGI:3923426  1110038B12Rik<Gt(Ayu21-B141)Imeg>
# 4   MGI:3923883  1110059E24Rik<Gt(Ayu21-W256)Imeg>
#
#                                          allele_name            allele_type  \
# 0                  targeted mutation 1.1, Velocigene               Targeted
# 1                    targeted mutation 1, Velocigene               Targeted
# 2  endonuclease-mediated mutation 1, Institute of...  Endonuclease-mediated
# 3  gene trap Ayu21-B141, Institute of Molecular E...           Gene trapped
# 4  gene trap Ayu21-W256, Institute of Molecular E...           Gene trapped
#
#          allele_attribute  PMID mgi_marker_id  marker_symbol marker_refseq_id  \
# 0  Null/knockout|Reporter   NaN   MGI:1915609  0610010K14Rik     NM_001177601
# 1  Null/knockout|Reporter   NaN   MGI:1915609  0610010K14Rik     NM_001177601
# 2           Null/knockout   NaN   MGI:1923511  0610040J01Rik     NM_001417897
# 3                     NaN   NaN   MGI:1916013  1110038B12Rik              NaN
# 4                     NaN   NaN   MGI:1913456  1110059E24Rik        NM_025423
#
#     marker_ensembl_id                                              mp_id  \
# 0  ENSMUSG00000020831                              MP:0005386,MP:0010768
# 1  ENSMUSG00000020831                                                NaN
# 2  ENSMUSG00000060512  MP:0005376,MP:0005378,MP:0005385,MP:0005387,MP...
# 3  ENSMUSG00000092203                                                NaN
# 4  ENSMUSG00000035171                                                NaN
#
#   synonyms                 marker_name
# 0      NaN  RIKEN cDNA 0610010K14 gene
# 1      NaN  RIKEN cDNA 0610010K14 gene
# 2      NaN  RIKEN cDNA 0610040J01 gene
# 3      NaN  RIKEN cDNA 1110038B12 gene
# 4      NaN  RIKEN cDNA 1110059E24 gene

# %%
# Quick inspection
mgi_phenotypic_allele.describe(include='all')
# Out:
#        mgi_allele_id              allele_symbol  \
# count         108940                     108940
# unique        108940                     108867
# top      MGI:5603349  Arhgap6/Hccs/Mid1<tm1Hzo>
# freq               1                          3
# mean             NaN                        NaN
# std              NaN                        NaN
# min              NaN                        NaN
# 25%              NaN                        NaN
# 50%              NaN                        NaN
# 75%              NaN                        NaN
# max              NaN                        NaN
#
#                                               allele_name allele_type  \
# count                                              108937      108940
# unique                                              42229          14
# top     endonuclease-mediated mutation 1, GemPharmatec...    Targeted
# freq                                                 8989       43851
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
#        allele_attribute          PMID mgi_marker_id  marker_symbol  \
# count             99813  5.049500e+04        108940         108940
# unique             1048           NaN         33118          33115
# top       Null/knockout           NaN    MGI:104735  Gt(ROSA)26Sor
# freq              37740           NaN          1477           1477
# mean                NaN  2.125652e+07           NaN            NaN
# std                 NaN  8.454548e+06           NaN            NaN
# min                 NaN  2.564500e+04           NaN            NaN
# 25%                 NaN  1.513958e+07           NaN            NaN
# 50%                 NaN  2.085037e+07           NaN            NaN
# 75%                 NaN  2.791696e+07           NaN            NaN
# max                 NaN  3.870304e+07           NaN            NaN
#
#        marker_refseq_id   marker_ensembl_id       mp_id  \
# count             89676               92229       44935
# unique            17298               17741       13572
# top           NM_013556  ENSMUSG00000086429  MP:0002873
# freq                247                1477        2068
# mean                NaN                 NaN         NaN
# std                 NaN                 NaN         NaN
# min                 NaN                 NaN         NaN
# 25%                 NaN                 NaN         NaN
# 50%                 NaN                 NaN         NaN
# 75%                 NaN                 NaN         NaN
# max                 NaN                 NaN         NaN
#
#                                             synonyms  \
# count                                          72449
# unique                                         70938
# top     deltaNLS Wld<S>|deltaNLS<R213A,R215A> Wld<S>
# freq                                               6
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# 50%                                              NaN
# 75%                                              NaN
# max                                              NaN
#
#                                 marker_name
# count                                108940
# unique                                31283
# top     gene trap ROSA 26, Philippe Soriano
# freq                                   1477
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN

# %%
mgi_phenotypic_allele['allele_type'].unique()
# Out:
# array(['Targeted', 'Endonuclease-mediated', 'Gene trapped',
#        'Chemically induced (ENU)', 'Transgenic', 'Spontaneous',
#        'Not Applicable', 'Transposon induced',
#        'Chemically induced (other)', 'Radiation induced',
#        'Chemically and radiation induced', 'QTL', 'Not Specified',
#        'Other'], dtype=object)

# %%
allele_map = {}
for idx, row in tqdm(mgi_phenotypic_allele.iterrows()):
    d = row.dropna().to_dict()
    _id = d.get('mgi_allele_id')
    if _id in allele_map:
        continue
    else:
        allele_attribute = d.get('allele_attribute', None)
        mammalian_phenotype_id = d.get('mp_id', None)
        props = {
            'uuid': _id,
            'displayName': d.get('allele_symbol', None),
            'description': d.get('allele_name', None),
            'citations': f'PMID:{d.get("PMID", None)}' if d.get('PMID', None) is not None else None,
            'allele_type': d.get('allele_type', None),
            'allele_attribute': allele_attribute.split('|') if allele_attribute is not None else None,
            'marker_ensembl_id': d.get('marker_ensembl_id'),
            'marker_symbol': d.get('marker_symbol'),
            'marker_mgi_id': d.get('mgi_marker_id'),
            'mammalian_phenotype_id': mammalian_phenotype_id.split(',') if mammalian_phenotype_id is not None else None
        }

        
        n = {
            '_id': _id,
            'labels': ['Allele'],
            'properties': {
                k:v for k,v in props.items() if v is not None
            }
        }
        allele_map[_id] = n
# Out:
# 108940it [00:13, 7906.16it/s]

# %% [markdown]
# ## Creating Genotype Nodes

# %% [markdown]
# Next we need to construct all the Genotypes, but also make the edges for the allelic combinations.

# %%
mgi_gene_pheno = download_tab_delimited_data(
    'https://www.informatics.jax.org/downloads/reports/MGI_GenePheno.rpt',
    ['allelic_composition', 'allele_symbols', 'allele_ids', 'genetic_background', 'mp_id', 'PMID', 'mgi_marker_id', 'mgi_genotype_id']
)

# %%
mgi_gene_pheno.head()
# Out:
#        allelic_composition allele_symbols   allele_ids     genetic_background  \
# 0  Rb1<tm1Tyj>/Rb1<tm1Tyj>    Rb1<tm1Tyj>  MGI:1857242  involves: 129S2/SvPas
# 1  Rb1<tm1Tyj>/Rb1<tm1Tyj>    Rb1<tm1Tyj>  MGI:1857242  involves: 129S2/SvPas
# 2  Rb1<tm1Tyj>/Rb1<tm1Tyj>    Rb1<tm1Tyj>  MGI:1857242  involves: 129S2/SvPas
# 3  Rb1<tm1Tyj>/Rb1<tm1Tyj>    Rb1<tm1Tyj>  MGI:1857242  involves: 129S2/SvPas
# 4  Rb1<tm1Tyj>/Rb1<tm1Tyj>    Rb1<tm1Tyj>  MGI:1857242  involves: 129S2/SvPas
#
#         mp_id      PMID mgi_marker_id mgi_genotype_id
# 0  MP:0000600  12529408     MGI:97874     MGI:2166359
# 1  MP:0001716  16449662     MGI:97874     MGI:2166359
# 2  MP:0001698  16449662     MGI:97874     MGI:2166359
# 3  MP:0001092  16449662     MGI:97874     MGI:2166359
# 4  MP:0000961  16449662     MGI:97874     MGI:2166359

# %%
genotype_map = {}

# %%
genotype_subset = mgi_gene_pheno[['mgi_genotype_id', 'allelic_composition', 'genetic_background']].groupby('mgi_genotype_id').first()
for _id, row in tqdm(genotype_subset.iterrows()):
    d = row.to_dict()
    if _id in genotype_map:
        continue
    else:
        n = {
            '_id': _id,
            'labels': ['Genotype'],
            'properties': {
                'uuid': _id,
                'displayName': d.get('allelic_composition'),
                'description': '',
                'allelic_composition': d.get('allelic_composition'),
                'genetic_background': d.get('genetic_background'),
                'url': f"https://www.informatics.jax.org/allele/genoview/{_id}"
            }
        }
        genotype_map[_id] = n
# Out:
# 48999it [00:02, 21341.51it/s]

# %%
# Subset out allele_id and genotype_id
geno2allele = mgi_gene_pheno[['allele_ids', 'mgi_genotype_id']]

# %%
geno2allele.head()
# Out:
#     allele_ids mgi_genotype_id
# 0  MGI:1857242     MGI:2166359
# 1  MGI:1857242     MGI:2166359
# 2  MGI:1857242     MGI:2166359
# 3  MGI:1857242     MGI:2166359
# 4  MGI:1857242     MGI:2166359

# %%
geno2allele_edges = []

for name, group in geno2allele.groupby('mgi_genotype_id'):
    allele_ids = set()
    for allele_str in list(group['allele_ids'].unique()):
        allele_ids.update(allele_str.split('|'))
    
    
    for allele_id in list(allele_ids):
        e = {
            'from': {
                'uuid': name
            },
            'to': {
                'uuid': allele_id
            },
            'label': 'has allele',
            'properties': {}
        }
        geno2allele_edges.append(e)

# %%
geno2allele_edges[0]
# Out:
# {'from': {'uuid': 'MGI:2166359'},
#  'to': {'uuid': 'MGI:1857242'},
#  'label': 'has allele',
#  'properties': {}}

# %% [markdown]
# Convert the DOIDs to EFOs where possible, and then explode out the genotypes for edges. Assumes EFO and MONDO are in.

# %%
mgi_disease_gene_model = download_tab_delimited_data('https://www.informatics.jax.org/downloads/reports/MGI_DiseaseGeneModel.rpt',
                                                    [
                                                        'human_gene_symbol',
                                                        'human_gene_name',
                                                        'hgnc_id',
                                                        'do_term',
                                                        'do_term_id',
                                                        'mouse_genotype_id',
                                                        'mouse_gene',
                                                        'mouse_mgi_id',
                                                        'facilities',
                                                        'repo_id'
                                                    ])

# %%
mgi_disease_gene_model.head()
# Out:
#   human_gene_symbol                 human_gene_name     hgnc_id  \
# 0              A1CF  APOBEC1 complementation factor  HGNC:24086
# 1               A2M           alpha-2-macroglobulin      HGNC:7
# 2               A2M           alpha-2-macroglobulin      HGNC:7
# 3               A2M           alpha-2-macroglobulin      HGNC:7
# 4               A2M           alpha-2-macroglobulin      HGNC:7
#
#                            do_term    do_term_id  \
# 0                             gout    DOID:13189
# 1              Alzheimer's disease    DOID:10652
# 2  background diabetic retinopathy    DOID:13208
# 3                         COVID-19  DOID:0080600
# 4               multiple sclerosis     DOID:2377
#
#                                    mouse_genotype_id mouse_gene mouse_mgi_id  \
# 0                                                NaN       A1cf  MGI:1917115
# 1  MGI:3693439|MGI:2684657|MGI:3721938|MGI:575438...        A2m  MGI:2449119
# 2                                                NaN        A2m  MGI:2449119
# 3    MGI:6402641|MGI:6455041|MGI:6431340|MGI:6415340        A2m  MGI:2449119
# 4  MGI:3835028|MGI:6305814|MGI:4461062|MGI:542970...        A2m  MGI:2449119
#
#                       facilities  \
# 0  APB|EMMA|EuMMCR|GPT|JAX|MMRRC
# 1            CMMR|GPT|MMRRC|SMOC
# 2            CMMR|GPT|MMRRC|SMOC
# 3            CMMR|GPT|MMRRC|SMOC
# 4            CMMR|GPT|MMRRC|SMOC
#
#                                              repo_id
# 0  EuMMCR:8829|EuMMCR:8828|EM:11705|APB:7708|MMRR...
# 1  CMMR:CMMR:ABAL|CMMR:CMMR:ABDJ|CMMR:CMMR:ABHA|N...
# 2  CMMR:CMMR:ABAL|CMMR:CMMR:ABDJ|CMMR:CMMR:ABHA|N...
# 3  CMMR:CMMR:ABAL|CMMR:CMMR:ABDJ|CMMR:CMMR:ABHA|N...
# 4  CMMR:CMMR:ABAL|CMMR:CMMR:ABDJ|CMMR:CMMR:ABHA|N...

# %%
mgi_disease_gene_model.dropna(subset=['mouse_genotype_id'], inplace=True)

# %%
doid_grouped = mgi_disease_gene_model[['do_term_id', 'mouse_genotype_id']].groupby('do_term_id')

# %%
with open('./resources/mappings/doid_efo.mapping.json', 'r') as f:
    doid_efo_mapping = json.load(f)

# %%
len(doid_efo_mapping.keys())
# Out:
# 6127

# %%
genotype2disease_edges = []

for doid, group in doid_grouped:
    if doid not in doid_efo_mapping:
        continue
    else:
        
        efo_hits = doid_efo_mapping[doid]
        if efo_hits is None:
            continue
        efo_id = efo_hits[0]
        genotype_ids = set()
        for genotype_str in list(group['mouse_genotype_id']):
            genotype_ids.update(genotype_str.split('|'))

        for genotype_id in list(genotype_ids):
            e = {
                'from': {
                    'uuid': genotype_id
                },
                'to': {
                    'uuid': efo_id
                },
                'label': 'is model of',
                'properties': {}
            }
            genotype2disease_edges.append(e)

# %%
genotype2disease_edges[10]
# Out:
# {'from': {'uuid': 'MGI:5314017'},
#  'to': {'uuid': 'EFO:1001352'},
#  'label': 'is model of',
#  'properties': {}}

# %% [markdown]
# # Node and Edge Generation

# %%
nodes = []
edges = []

# %%
nodes.extend(genotype_map.values())
print(len(nodes))
edges.extend(geno2allele_edges)
print(len(edges))
# Out:
# 48999
# 50361

# %%
nodes.extend(allele_map.values())
print(len(nodes))
edges.extend(genotype2disease_edges)
print(len(edges))
# Out:
# 157939
# 57477

# %%
with gzip.open(os.path.join(processed_data, 'alliance_disease_models_node.jsonl.gz'), 'wt', encoding='utf-8') as outfile:
    for x in tqdm(nodes):
        outfile.write(json.dumps(x) + '\n')

with gzip.open(os.path.join(processed_data, 'alliance_disease_models_edge.jsonl.gz'), 'wt', encoding='utf-8') as outfile:
    for x in tqdm(edges):
        outfile.write(json.dumps(x) + '\n')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 157939/157939 [00:03<00:00, 45774.97it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 57477/57477 [00:00<00:00, 122554.33it/s]

# %%
metadata = {
    "_meta": {
        "version": "0.1.3",
        "date_updated": "2024-02-17",
        "maintainer": "BioBox Analytics"
    },
    "key": "alliance_disease_models",
    "name": "Alliance Genome - Animal Models of Disease",
    "description": "Extraction of alleles-genotypes-diseases reports from MGI.",
    "source": [
        {
            "uri": "https://www.informatics.jax.org/",
            "type": "doc"
        },
        {
            "uri": "https://www.informatics.jax.org/downloads/reports/index.html#pheno",
            "type": "data",
            "version": "7.1.0"
        }
    ],
    "concepts": {
        "Allele": {
            "label": "Allele",
            "dbLabel": "Allele",
            "definition": "One of a set of sequence features known to exist at a particular genomic location. An allele is a seqeunce feature at a genomic location where variation occurs (i.e. where >1 different sequence is known to exist). An allele can span only the extent of sequence known to vary (e.g. a single base SNP, or short insertion), or it can span a larger extent that includes one or more variable features as proper parts (e.g. a 'gene allele' that spans the extent of an entire gene which contains several sequence alterations). Alleles can carry 'reference' or 'variant' sequence - depending on whether the its 'state' matches that considered to be the reference at that location. Alleles whose state differs from the reference are called 'variant alleles', and those that match the reference are called 'reference alleles'. What is considered the 'reference' state at a particular location may vary, depending on the context/goal of a particular analysis. A 'sequence alteration' is a 'variant allele' that varies along its entire extent (i.e every position varies from that of some defined reference sequence)."
        },
        "Genotype": {
            "label": "Genotype",
            "dbLabel": "Genotype",
            "definition": "The total sum of the genetic information of an organism that is known and relevant to the experiment being performed, including chromosomal, plasmid, viral or other genetic material which has been introduced into the organism either prior to or during the experiment. Information, making the distinction between the actual physical material (e.g. a cell) and the information about the genetic content (genotype)."
        }
    },
    "relationships": {
        "has allele": {
            "from": "Genotype",
            "to": "Allele"
        },
        "is model of": {
            "from": "Genotype",
            "to": "Disease"
        }
    }
}
with open(os.path.join(processed_data, 'alliance_disease_models_metadata.json'), 'w') as f:
    json.dump(metadata, f)

# %% [markdown]
# # Scratch

# %%
from neo4j import GraphDatabase

driver = GraphDatabase.driver("bolt+ssc://pr-1645-neo4j-pr-1645.frzb.biobox.to:7687", auth=('neo4j', 'EpPRhKPyJUxgC6gv'))

# %%
res = requests.get('http://www.ensembl.org/biomart/martservice?query=<?xml version="1.0" encoding="UTF-8"?><!DOCTYPE Query><Query  virtualSchemaName = "default" formatter = "TSV" header = "0" uniqueRows = "0" count = "" datasetConfigVersion = "0.6" ><Dataset name = "hsapiens_gene_ensembl" interface = "default" ><Attribute name = "ensembl_gene_id" /><Attribute name = "mmusculus_homolog_ensembl_gene" /></Dataset></Query>')

# %%
human_mouse_homolog = pd.read_table(io.StringIO(res.text), header=None)

# %%
human_mouse_homolog.columns = ['hsapiens', 'mmusculus']

# %%
human_mouse_homolog.dropna(subset='mmusculus', inplace=True)
human_mouse_homolog.set_index('mmusculus', inplace=True)

# %%
human_mouse_homolog.loc['ENSMUSG00000064341']['hsapiens']
# Out:
# 'ENSG00000198888'

# %%
records, summary, _ = driver.execute_query(
    """
    MATCH (a:Allele)
    WHERE a.marker_ensembl_id is not null
    RETURN a.uuid, a.marker_ensembl_id
    """,
    database_="bx-d52b76a6-2e9b-4d53-894e-58e818cff0f2"
)

# %%
batch = []

for r in records:
    allele_id = r.get('a.uuid')
    mouse_gene_id = r.get('a.marker_ensembl_id')
 
    try:
        hsapien_id = human_mouse_homolog.loc[mouse_gene_id]['hsapiens']
        batch.append({'source': allele_id, 'target': hsapien_id})
    except:
        continue

# %%
len(batch)
# Out:
# 87157

# %%
driver.execute_query(
    """
    UNWIND $batch as b
    MATCH (a:Allele {uuid: b.source})
    MATCH (g:Gene { uuid: b.target})
    MERGE (a)-[:`on target`]->(g)
    """,
    database_="bx-d52b76a6-2e9b-4d53-894e-58e818cff0f2",
    batch=batch
)
# Out:
# EagerResult(records=[], summary=<neo4j._work.summary.ResultSummary object at 0x12f856490>, keys=[])

# %%
res = requests.post("https://pr-1625-rest.frzb.biobox.to/bioref/query/objects",
                   json={ "query": "(Genotype)-> is model of ->(Disease)<- is implicated in severity of <-(Gene)", "class": "Gene", "pagination": { "limit": 100, "offset": 0, "sortBy": { "key": "uuid", "descending": False } } },
                   headers= {
                       'x-biobox-orgid': 'bx-3079fc5a-1ed1-4e17-a482-e38efdbfe837',
                        'Authorization': f"Bearer {}"
                   })

# %%
res.json()
# Out:
# [{'class': 'Gene',
#   'variable': 'g2',
#   'statement': 'MATCH\n(g:`Genotype`)-[_r:`is model of`]->(d:`Disease`)<-[_r2:`is implicated in severity of`]-(g2:`Gene`)RETURN DISTINCT g2\nSKIP 0\nLIMIT 100',
#   'countStatement': 'MATCH\n(g:`Genotype`)-[_r:`is model of`]->(d:`Disease`)<-[_r2:`is implicated in severity of`]-(g2:`Gene`)RETURN count(DISTINCT g2)',
#   'total': 327,
#   'offset': 0,
#   'count': 100,
#   'data': [{'biotype': 'protein_coding',
#     'symbol': 'ALX4',
#     'level': 'manually annotated loci',
#     'displayName': 'ALX4',
#     'start': 44260440,
#     'source': 'HAVANA',
#     'chr': '11',
#     'uuid': 'ENSG00000052850',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000052850.8',
#     'HGNC': 'HGNC:450',
#     'end': 44310139,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'ARID1A',
#     'level': 'verified loci',
#     'displayName': 'ARID1A',
#     'start': 26693236,
#     'source': 'HAVANA',
#     'chr': '1',
#     'uuid': 'ENSG00000117713',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000117713.21',
#     'HGNC': 'HGNC:11110',
#     'end': 26782104,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'ARID2',
#     'level': 'manually annotated loci',
#     'displayName': 'ARID2',
#     'start': 45729706,
#     'source': 'HAVANA',
#     'chr': '12',
#     'uuid': 'ENSG00000189079',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000189079.18',
#     'HGNC': 'HGNC:18037',
#     'end': 45908040,
#     'tag': ['ncRNA_host', 'overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'BIRC3',
#     'level': 'verified loci',
#     'displayName': 'BIRC3',
#     'start': 102317484,
#     'source': 'HAVANA',
#     'chr': '11',
#     'uuid': 'ENSG00000023445',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000023445.17',
#     'HGNC': 'HGNC:591',
#     'end': 102339403,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'CASP8',
#     'level': 'verified loci',
#     'displayName': 'CASP8',
#     'start': 201233443,
#     'source': 'HAVANA',
#     'chr': '2',
#     'uuid': 'ENSG00000064012',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000064012.24',
#     'HGNC': 'HGNC:1509',
#     'end': 201361836,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'CSF1R',
#     'level': 'manually annotated loci',
#     'displayName': 'CSF1R',
#     'start': 150053291,
#     'source': 'HAVANA',
#     'chr': '5',
#     'uuid': 'ENSG00000182578',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000182578.14',
#     'HGNC': 'HGNC:2433',
#     'end': 150113372,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'CTNNB1',
#     'level': 'verified loci',
#     'displayName': 'CTNNB1',
#     'start': 41194741,
#     'source': 'HAVANA',
#     'chr': '3',
#     'uuid': 'ENSG00000168036',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000168036.18',
#     'HGNC': 'HGNC:2514',
#     'end': 41260096,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'EFTUD2',
#     'level': 'manually annotated loci',
#     'displayName': 'EFTUD2',
#     'start': 44849948,
#     'source': 'HAVANA',
#     'chr': '17',
#     'uuid': 'ENSG00000108883',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000108883.13',
#     'HGNC': 'HGNC:30858',
#     'end': 44899445,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'FES',
#     'level': 'manually annotated loci',
#     'displayName': 'FES',
#     'start': 90883695,
#     'source': 'HAVANA',
#     'chr': '15',
#     'uuid': 'ENSG00000182511',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000182511.12',
#     'HGNC': 'HGNC:3657',
#     'end': 90895776,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'FGFR2',
#     'level': 'verified loci',
#     'displayName': 'FGFR2',
#     'start': 121478332,
#     'source': 'HAVANA',
#     'chr': '10',
#     'uuid': 'ENSG00000066468',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000066468.24',
#     'HGNC': 'HGNC:3689',
#     'end': 121598458,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'FLT3',
#     'level': 'manually annotated loci',
#     'displayName': 'FLT3',
#     'start': 28003274,
#     'source': 'HAVANA',
#     'chr': '13',
#     'uuid': 'ENSG00000122025',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000122025.15',
#     'HGNC': 'HGNC:3765',
#     'end': 28100592,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'FUBP1',
#     'level': 'manually annotated loci',
#     'displayName': 'FUBP1',
#     'start': 77944055,
#     'source': 'HAVANA',
#     'chr': '1',
#     'uuid': 'ENSG00000162613',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000162613.18',
#     'HGNC': 'HGNC:4004',
#     'end': 77979110,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'GPX1',
#     'level': 'manually annotated loci',
#     'displayName': 'GPX1',
#     'start': 49357174,
#     'source': 'HAVANA',
#     'chr': '3',
#     'uuid': 'ENSG00000233276',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000233276.9',
#     'HGNC': 'HGNC:4553',
#     'end': 49358605,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'HNRNPAB',
#     'level': 'manually annotated loci',
#     'displayName': 'HNRNPAB',
#     'start': 178204533,
#     'source': 'HAVANA',
#     'chr': '5',
#     'uuid': 'ENSG00000197451',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000197451.12',
#     'HGNC': 'HGNC:5034',
#     'end': 178211163,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'IL18',
#     'level': 'verified loci',
#     'displayName': 'IL18',
#     'start': 112143253,
#     'source': 'HAVANA',
#     'chr': '11',
#     'uuid': 'ENSG00000150782',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000150782.12',
#     'HGNC': 'HGNC:5986',
#     'end': 112164096,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'KDM6A',
#     'level': 'manually annotated loci',
#     'displayName': 'KDM6A',
#     'start': 44873188,
#     'source': 'HAVANA',
#     'chr': 'X',
#     'uuid': 'ENSG00000147050',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000147050.18',
#     'HGNC': 'HGNC:12637',
#     'end': 45112779,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'LECT2',
#     'level': 'verified loci',
#     'displayName': 'LECT2',
#     'start': 135922279,
#     'source': 'HAVANA',
#     'chr': '5',
#     'uuid': 'ENSG00000145826',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000145826.9',
#     'HGNC': 'HGNC:6550',
#     'end': 135954983,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'LRP1B',
#     'level': 'verified loci',
#     'displayName': 'LRP1B',
#     'start': 140231423,
#     'source': 'HAVANA',
#     'chr': '2',
#     'uuid': 'ENSG00000168702',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000168702.18',
#     'HGNC': 'HGNC:6693',
#     'end': 142131016,
#     'tag': ['ncRNA_host', 'overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'MAP4K4',
#     'level': 'manually annotated loci',
#     'displayName': 'MAP4K4',
#     'start': 101696850,
#     'source': 'HAVANA',
#     'chr': '2',
#     'uuid': 'ENSG00000071054',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000071054.17',
#     'HGNC': 'HGNC:6866',
#     'end': 101894690,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'MBL2',
#     'level': 'manually annotated loci',
#     'displayName': 'MBL2',
#     'start': 52765380,
#     'source': 'HAVANA',
#     'chr': '10',
#     'uuid': 'ENSG00000165471',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000165471.7',
#     'HGNC': 'HGNC:6922',
#     'end': 52772784,
#     'tag': ['']},
#    {'biotype': 'miRNA',
#     'symbol': 'MIR195',
#     'level': 'automatically annotated loci',
#     'displayName': 'MIR195',
#     'start': 7017615,
#     'source': 'ENSEMBL',
#     'chr': '17',
#     'uuid': 'ENSG00000284112',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000284112.1',
#     'HGNC': 'HGNC:31566',
#     'end': 7017701,
#     'tag': ['']},
#    {'biotype': 'miRNA',
#     'symbol': 'MIR212',
#     'level': 'automatically annotated loci',
#     'displayName': 'MIR212',
#     'start': 2050271,
#     'source': 'ENSEMBL',
#     'chr': '17',
#     'uuid': 'ENSG00000267195',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000267195.1',
#     'HGNC': 'HGNC:31589',
#     'end': 2050380,
#     'tag': ['']},
#    {'biotype': 'miRNA',
#     'symbol': 'MIR27A',
#     'level': 'automatically annotated loci',
#     'displayName': 'MIR27A',
#     'start': 13836440,
#     'source': 'ENSEMBL',
#     'chr': '19',
#     'uuid': 'ENSG00000207808',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000207808.1',
#     'HGNC': 'HGNC:31613',
#     'end': 13836517,
#     'tag': ['']},
#    {'biotype': 'miRNA',
#     'symbol': 'MIR302D',
#     'level': 'automatically annotated loci',
#     'displayName': 'MIR302D',
#     'start': 112648004,
#     'source': 'ENSEMBL',
#     'chr': '4',
#     'uuid': 'ENSG00000199145',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000199145.1',
#     'HGNC': 'HGNC:31765',
#     'end': 112648071,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'MYD88',
#     'level': 'verified loci',
#     'displayName': 'MYD88',
#     'start': 38138552,
#     'source': 'HAVANA',
#     'chr': '3',
#     'uuid': 'ENSG00000172936',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000172936.18',
#     'HGNC': 'HGNC:7562',
#     'end': 38143024,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'NRAS',
#     'level': 'manually annotated loci',
#     'displayName': 'NRAS',
#     'start': 114704469,
#     'source': 'HAVANA',
#     'chr': '1',
#     'uuid': 'ENSG00000213281',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000213281.5',
#     'HGNC': 'HGNC:7989',
#     'end': 114716771,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'PIK3CA',
#     'level': 'verified loci',
#     'displayName': 'PIK3CA',
#     'start': 179148114,
#     'source': 'HAVANA',
#     'chr': '3',
#     'uuid': 'ENSG00000121879',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000121879.6',
#     'HGNC': 'HGNC:8975',
#     'end': 179240093,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'PLCG1',
#     'level': 'manually annotated loci',
#     'displayName': 'PLCG1',
#     'start': 41136960,
#     'source': 'HAVANA',
#     'chr': '20',
#     'uuid': 'ENSG00000124181',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000124181.15',
#     'HGNC': 'HGNC:9065',
#     'end': 41196801,
#     'tag': ['ncRNA_host', 'overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'RIT1',
#     'level': 'manually annotated loci',
#     'displayName': 'RIT1',
#     'start': 155897808,
#     'source': 'HAVANA',
#     'chr': '1',
#     'uuid': 'ENSG00000143622',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000143622.12',
#     'HGNC': 'HGNC:10023',
#     'end': 155911404,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'ENSG00000285897',
#     'level': 'manually annotated loci',
#     'displayName': 'ENSG00000285897',
#     'start': 58345206,
#     'source': 'HAVANA',
#     'chr': '17',
#     'uuid': 'ENSG00000285897',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000285897.1',
#     'HGNC': '',
#     'end': 58417595,
#     'tag': ['overlapping_locus', 'readthrough_gene']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SLC38A1',
#     'level': 'verified loci',
#     'displayName': 'SLC38A1',
#     'start': 46183063,
#     'source': 'HAVANA',
#     'chr': '12',
#     'uuid': 'ENSG00000111371',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000111371.16',
#     'HGNC': 'HGNC:13447',
#     'end': 46270017,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SLC7A5',
#     'level': 'manually annotated loci',
#     'displayName': 'SLC7A5',
#     'start': 87830023,
#     'source': 'HAVANA',
#     'chr': '16',
#     'uuid': 'ENSG00000103257',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000103257.9',
#     'HGNC': 'HGNC:11063',
#     'end': 87869507,
#     'tag': ['ncRNA_host']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SMC3',
#     'level': 'manually annotated loci',
#     'displayName': 'SMC3',
#     'start': 110567684,
#     'source': 'HAVANA',
#     'chr': '10',
#     'uuid': 'ENSG00000108055',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000108055.11',
#     'HGNC': 'HGNC:2468',
#     'end': 110606048,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SOX30',
#     'level': 'manually annotated loci',
#     'displayName': 'SOX30',
#     'start': 157625679,
#     'source': 'HAVANA',
#     'chr': '5',
#     'uuid': 'ENSG00000039600',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000039600.11',
#     'HGNC': 'HGNC:30635',
#     'end': 157671480,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SPOCK1',
#     'level': 'manually annotated loci',
#     'displayName': 'SPOCK1',
#     'start': 136975298,
#     'source': 'HAVANA',
#     'chr': '5',
#     'uuid': 'ENSG00000152377',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000152377.15',
#     'HGNC': 'HGNC:11251',
#     'end': 137598379,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SPOP',
#     'level': 'manually annotated loci',
#     'displayName': 'SPOP',
#     'start': 49598884,
#     'source': 'HAVANA',
#     'chr': '17',
#     'uuid': 'ENSG00000121067',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000121067.19',
#     'HGNC': 'HGNC:11254',
#     'end': 49678163,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'TET2',
#     'level': 'manually annotated loci',
#     'displayName': 'TET2',
#     'start': 105145875,
#     'source': 'HAVANA',
#     'chr': '4',
#     'uuid': 'ENSG00000168769',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000168769.14',
#     'HGNC': 'HGNC:25941',
#     'end': 105279816,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'XPO1',
#     'level': 'manually annotated loci',
#     'displayName': 'XPO1',
#     'start': 61476032,
#     'source': 'HAVANA',
#     'chr': '2',
#     'uuid': 'ENSG00000082898',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000082898.19',
#     'HGNC': 'HGNC:12825',
#     'end': 61538741,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'XPO5',
#     'level': 'manually annotated loci',
#     'displayName': 'XPO5',
#     'start': 43522334,
#     'source': 'HAVANA',
#     'chr': '6',
#     'uuid': 'ENSG00000124571',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000124571.18',
#     'HGNC': 'HGNC:17675',
#     'end': 43576038,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'XRCC1',
#     'level': 'verified loci',
#     'displayName': 'XRCC1',
#     'start': 43543311,
#     'source': 'HAVANA',
#     'chr': '19',
#     'uuid': 'ENSG00000073050',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000073050.12',
#     'HGNC': 'HGNC:12828',
#     'end': 43580473,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'ZFHX3',
#     'level': 'manually annotated loci',
#     'displayName': 'ZFHX3',
#     'start': 72782885,
#     'source': 'HAVANA',
#     'chr': '16',
#     'uuid': 'ENSG00000140836',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000140836.17',
#     'HGNC': 'HGNC:777',
#     'end': 73891871,
#     'tag': ['ncRNA_host']},
#    {'biotype': 'protein_coding',
#     'symbol': 'ADAM28',
#     'level': 'verified loci',
#     'displayName': 'ADAM28',
#     'start': 24294069,
#     'source': 'HAVANA',
#     'chr': '8',
#     'uuid': 'ENSG00000042980',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000042980.14',
#     'HGNC': 'HGNC:206',
#     'end': 24359014,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'CADM1',
#     'level': 'verified loci',
#     'displayName': 'CADM1',
#     'start': 115169218,
#     'source': 'HAVANA',
#     'chr': '11',
#     'uuid': 'ENSG00000182985',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000182985.19',
#     'HGNC': 'HGNC:5951',
#     'end': 115504957,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'CBX7',
#     'level': 'manually annotated loci',
#     'displayName': 'CBX7',
#     'start': 39120167,
#     'source': 'HAVANA',
#     'chr': '22',
#     'uuid': 'ENSG00000100307',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000100307.13',
#     'HGNC': 'HGNC:1557',
#     'end': 39152680,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'DUSP1',
#     'level': 'manually annotated loci',
#     'displayName': 'DUSP1',
#     'start': 172768096,
#     'source': 'HAVANA',
#     'chr': '5',
#     'uuid': 'ENSG00000120129',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000120129.6',
#     'HGNC': 'HGNC:3064',
#     'end': 172771195,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'FBXO11',
#     'level': 'manually annotated loci',
#     'displayName': 'FBXO11',
#     'start': 47789316,
#     'source': 'HAVANA',
#     'chr': '2',
#     'uuid': 'ENSG00000138081',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000138081.22',
#     'HGNC': 'HGNC:13590',
#     'end': 47906498,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'GNRH1',
#     'level': 'manually annotated loci',
#     'displayName': 'GNRH1',
#     'start': 25419258,
#     'source': 'HAVANA',
#     'chr': '8',
#     'uuid': 'ENSG00000147437',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000147437.10',
#     'HGNC': 'HGNC:4419',
#     'end': 25424654,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'ENSG00000293552',
#     'level': 'manually annotated loci',
#     'displayName': 'ENSG00000293552',
#     'start': 6716157,
#     'source': 'HAVANA',
#     'chr': '9',
#     'uuid': 'ENSG00000293552',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000293552.1',
#     'HGNC': '',
#     'end': 7077263,
#     'tag': ['overlapping_locus', 'readthrough_gene']},
#    {'biotype': 'protein_coding',
#     'symbol': 'KSR1',
#     'level': 'verified loci',
#     'displayName': 'KSR1',
#     'start': 27456448,
#     'source': 'HAVANA',
#     'chr': '17',
#     'uuid': 'ENSG00000141068',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000141068.17',
#     'HGNC': 'HGNC:6465',
#     'end': 27626438,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'LHCGR',
#     'level': 'verified loci',
#     'displayName': 'LHCGR',
#     'start': 48686774,
#     'source': 'HAVANA',
#     'chr': '2',
#     'uuid': 'ENSG00000138039',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000138039.15',
#     'HGNC': 'HGNC:6585',
#     'end': 48755730,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'MCPH1',
#     'level': 'manually annotated loci',
#     'displayName': 'MCPH1',
#     'start': 6406592,
#     'source': 'HAVANA',
#     'chr': '8',
#     'uuid': 'ENSG00000147316',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000147316.15',
#     'HGNC': 'HGNC:6954',
#     'end': 6648508,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'MYC',
#     'level': 'verified loci',
#     'displayName': 'MYC',
#     'start': 127735434,
#     'source': 'HAVANA',
#     'chr': '8',
#     'uuid': 'ENSG00000136997',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000136997.22',
#     'HGNC': 'HGNC:7553',
#     'end': 127742951,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'TGFB1',
#     'level': 'verified loci',
#     'displayName': 'TGFB1',
#     'start': 41301587,
#     'source': 'HAVANA',
#     'chr': '19',
#     'uuid': 'ENSG00000105329',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000105329.11',
#     'HGNC': 'HGNC:11766',
#     'end': 41353922,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'TNFAIP3',
#     'level': 'manually annotated loci',
#     'displayName': 'TNFAIP3',
#     'start': 137867214,
#     'source': 'HAVANA',
#     'chr': '6',
#     'uuid': 'ENSG00000118503',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000118503.18',
#     'HGNC': 'HGNC:11896',
#     'end': 137883314,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'TSG101',
#     'level': 'verified loci',
#     'displayName': 'TSG101',
#     'start': 18468336,
#     'source': 'HAVANA',
#     'chr': '11',
#     'uuid': 'ENSG00000074319',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000074319.13',
#     'HGNC': 'HGNC:15971',
#     'end': 18526951,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'TWIST1',
#     'level': 'manually annotated loci',
#     'displayName': 'TWIST1',
#     'start': 19020991,
#     'source': 'HAVANA',
#     'chr': '7',
#     'uuid': 'ENSG00000122691',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000122691.13',
#     'HGNC': 'HGNC:12428',
#     'end': 19117636,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'UBR5',
#     'level': 'verified loci',
#     'displayName': 'UBR5',
#     'start': 102252273,
#     'source': 'HAVANA',
#     'chr': '8',
#     'uuid': 'ENSG00000104517',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000104517.13',
#     'HGNC': 'HGNC:16806',
#     'end': 102412759,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'CDKN2A',
#     'level': 'verified loci',
#     'displayName': 'CDKN2A',
#     'start': 21967752,
#     'source': 'HAVANA',
#     'chr': '9',
#     'uuid': 'ENSG00000147889',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000147889.18',
#     'HGNC': 'HGNC:1787',
#     'end': 21995301,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'EZH2',
#     'level': 'manually annotated loci',
#     'displayName': 'EZH2',
#     'start': 148807257,
#     'source': 'HAVANA',
#     'chr': '7',
#     'uuid': 'ENSG00000106462',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000106462.12',
#     'HGNC': 'HGNC:3527',
#     'end': 148884321,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'BCL2',
#     'level': 'manually annotated loci',
#     'displayName': 'BCL2',
#     'start': 63123346,
#     'source': 'HAVANA',
#     'chr': '18',
#     'uuid': 'ENSG00000171791',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000171791.14',
#     'HGNC': 'HGNC:990',
#     'end': 63320128,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'NF1',
#     'level': 'manually annotated loci',
#     'displayName': 'NF1',
#     'start': 31094927,
#     'source': 'HAVANA',
#     'chr': '17',
#     'uuid': 'ENSG00000196712',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000196712.20',
#     'HGNC': 'HGNC:7765',
#     'end': 31382116,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'NSD1',
#     'level': 'verified loci',
#     'displayName': 'NSD1',
#     'start': 177131830,
#     'source': 'HAVANA',
#     'chr': '5',
#     'uuid': 'ENSG00000165671',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000165671.22',
#     'HGNC': 'HGNC:14234',
#     'end': 177300213,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'PHF6',
#     'level': 'manually annotated loci',
#     'displayName': 'PHF6',
#     'start': 134373288,
#     'source': 'HAVANA',
#     'chr': 'X',
#     'uuid': 'ENSG00000156531',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000156531.18',
#     'HGNC': 'HGNC:18145',
#     'end': 134428791,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SAMHD1',
#     'level': 'manually annotated loci',
#     'displayName': 'SAMHD1',
#     'start': 36890229,
#     'source': 'HAVANA',
#     'chr': '20',
#     'uuid': 'ENSG00000101347',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000101347.11',
#     'HGNC': 'HGNC:15925',
#     'end': 36951893,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SRSF2',
#     'level': 'manually annotated loci',
#     'displayName': 'SRSF2',
#     'start': 76734115,
#     'source': 'HAVANA',
#     'chr': '17',
#     'uuid': 'ENSG00000161547',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000161547.17',
#     'HGNC': 'HGNC:10783',
#     'end': 76737333,
#     'tag': ['ncRNA_host']},
#    {'biotype': 'protein_coding',
#     'symbol': 'CHD4',
#     'level': 'manually annotated loci',
#     'displayName': 'CHD4',
#     'start': 6570082,
#     'source': 'HAVANA',
#     'chr': '12',
#     'uuid': 'ENSG00000111642',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000111642.16',
#     'HGNC': 'HGNC:1919',
#     'end': 6614524,
#     'tag': ['ncRNA_host', 'overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'CHRNB4',
#     'level': 'verified loci',
#     'displayName': 'CHRNB4',
#     'start': 78624111,
#     'source': 'HAVANA',
#     'chr': '15',
#     'uuid': 'ENSG00000117971',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000117971.12',
#     'HGNC': 'HGNC:1964',
#     'end': 78727754,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'CMPK1',
#     'level': 'manually annotated loci',
#     'displayName': 'CMPK1',
#     'start': 47333790,
#     'source': 'HAVANA',
#     'chr': '1',
#     'uuid': 'ENSG00000162368',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000162368.15',
#     'HGNC': 'HGNC:18170',
#     'end': 47394866,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'CYCS',
#     'level': 'manually annotated loci',
#     'displayName': 'CYCS',
#     'start': 25118656,
#     'source': 'HAVANA',
#     'chr': '7',
#     'uuid': 'ENSG00000172115',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000172115.9',
#     'HGNC': 'HGNC:19986',
#     'end': 25125260,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'ERCC1',
#     'level': 'verified loci',
#     'displayName': 'ERCC1',
#     'start': 45407334,
#     'source': 'HAVANA',
#     'chr': '19',
#     'uuid': 'ENSG00000012061',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000012061.17',
#     'HGNC': 'HGNC:3433',
#     'end': 45478828,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'ESCO2',
#     'level': 'manually annotated loci',
#     'displayName': 'ESCO2',
#     'start': 27771949,
#     'source': 'HAVANA',
#     'chr': '8',
#     'uuid': 'ENSG00000171320',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000171320.15',
#     'HGNC': 'HGNC:27230',
#     'end': 27812640,
#     'tag': ['ncRNA_host']},
#    {'biotype': 'protein_coding',
#     'symbol': 'FGFR4',
#     'level': 'manually annotated loci',
#     'displayName': 'FGFR4',
#     'start': 177086905,
#     'source': 'HAVANA',
#     'chr': '5',
#     'uuid': 'ENSG00000160867',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000160867.15',
#     'HGNC': 'HGNC:3691',
#     'end': 177098144,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'FH',
#     'level': 'manually annotated loci',
#     'displayName': 'FH',
#     'start': 241497511,
#     'source': 'HAVANA',
#     'chr': '1',
#     'uuid': 'ENSG00000091483',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000091483.8',
#     'HGNC': 'HGNC:3700',
#     'end': 241519799,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'FOXA1',
#     'level': 'manually annotated loci',
#     'displayName': 'FOXA1',
#     'start': 37589552,
#     'source': 'HAVANA',
#     'chr': '14',
#     'uuid': 'ENSG00000129514',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000129514.8',
#     'HGNC': 'HGNC:5021',
#     'end': 37596059,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'HNRNPL',
#     'level': 'manually annotated loci',
#     'displayName': 'HNRNPL',
#     'start': 38836370,
#     'source': 'HAVANA',
#     'chr': '19',
#     'uuid': 'ENSG00000104824',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000104824.18',
#     'HGNC': 'HGNC:5045',
#     'end': 38852347,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'IDH2',
#     'level': 'verified loci',
#     'displayName': 'IDH2',
#     'start': 90083045,
#     'source': 'HAVANA',
#     'chr': '15',
#     'uuid': 'ENSG00000182054',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000182054.10',
#     'HGNC': 'HGNC:5383',
#     'end': 90102477,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'MAP2K4',
#     'level': 'verified loci',
#     'displayName': 'MAP2K4',
#     'start': 12020829,
#     'source': 'HAVANA',
#     'chr': '17',
#     'uuid': 'ENSG00000065559',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000065559.15',
#     'HGNC': 'HGNC:6844',
#     'end': 12143830,
#     'tag': ['ncRNA_host', 'overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'MAP2K7',
#     'level': 'manually annotated loci',
#     'displayName': 'MAP2K7',
#     'start': 7903843,
#     'source': 'HAVANA',
#     'chr': '19',
#     'uuid': 'ENSG00000076984',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000076984.18',
#     'HGNC': 'HGNC:6847',
#     'end': 7914478,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'MAP3K1',
#     'level': 'verified loci',
#     'displayName': 'MAP3K1',
#     'start': 56815549,
#     'source': 'HAVANA',
#     'chr': '5',
#     'uuid': 'ENSG00000095015',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000095015.6',
#     'HGNC': 'HGNC:6848',
#     'end': 56896152,
#     'tag': ['']},
#    {'biotype': 'miRNA',
#     'symbol': 'MIR136',
#     'level': 'automatically annotated loci',
#     'displayName': 'MIR136',
#     'start': 100884702,
#     'source': 'ENSEMBL',
#     'chr': '14',
#     'uuid': 'ENSG00000207942',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000207942.2',
#     'HGNC': 'HGNC:31522',
#     'end': 100884783,
#     'tag': ['']},
#    {'biotype': 'miRNA',
#     'symbol': 'MIR146A',
#     'level': 'automatically annotated loci',
#     'displayName': 'MIR146A',
#     'start': 160485352,
#     'source': 'ENSEMBL',
#     'chr': '5',
#     'uuid': 'ENSG00000283733',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000283733.1',
#     'HGNC': 'HGNC:31533',
#     'end': 160485450,
#     'tag': ['']},
#    {'biotype': 'miRNA',
#     'symbol': 'MIR193A',
#     'level': 'automatically annotated loci',
#     'displayName': 'MIR193A',
#     'start': 31559996,
#     'source': 'ENSEMBL',
#     'chr': '17',
#     'uuid': 'ENSG00000207614',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000207614.1',
#     'HGNC': 'HGNC:31563',
#     'end': 31560083,
#     'tag': ['']},
#    {'biotype': 'miRNA',
#     'symbol': 'MIR222',
#     'level': 'automatically annotated loci',
#     'displayName': 'MIR222',
#     'start': 45747015,
#     'source': 'ENSEMBL',
#     'chr': 'X',
#     'uuid': 'ENSG00000207725',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000207725.3',
#     'HGNC': 'HGNC:31602',
#     'end': 45747124,
#     'tag': ['']},
#    {'biotype': 'miRNA',
#     'symbol': 'MIR9-3',
#     'level': 'automatically annotated loci',
#     'displayName': 'MIR9-3',
#     'start': 89368017,
#     'source': 'ENSEMBL',
#     'chr': '15',
#     'uuid': 'ENSG00000284329',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000284329.1',
#     'HGNC': 'HGNC:31646',
#     'end': 89368106,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'MTHFR',
#     'level': 'manually annotated loci',
#     'displayName': 'MTHFR',
#     'start': 11785723,
#     'source': 'HAVANA',
#     'chr': '1',
#     'uuid': 'ENSG00000177000',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000177000.13',
#     'HGNC': 'HGNC:7436',
#     'end': 11806455,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'POLE',
#     'level': 'verified loci',
#     'displayName': 'POLE',
#     'start': 132623753,
#     'source': 'HAVANA',
#     'chr': '12',
#     'uuid': 'ENSG00000177084',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000177084.19',
#     'HGNC': 'HGNC:9177',
#     'end': 132687376,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'PRDM1',
#     'level': 'verified loci',
#     'displayName': 'PRDM1',
#     'start': 105993463,
#     'source': 'HAVANA',
#     'chr': '6',
#     'uuid': 'ENSG00000057657',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000057657.17',
#     'HGNC': 'HGNC:9346',
#     'end': 106109939,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'PTGS2',
#     'level': 'manually annotated loci',
#     'displayName': 'PTGS2',
#     'start': 186671791,
#     'source': 'HAVANA',
#     'chr': '1',
#     'uuid': 'ENSG00000073756',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000073756.13',
#     'HGNC': 'HGNC:9605',
#     'end': 186680922,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'PTPN13',
#     'level': 'verified loci',
#     'displayName': 'PTPN13',
#     'start': 86594315,
#     'source': 'HAVANA',
#     'chr': '4',
#     'uuid': 'ENSG00000163629',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000163629.13',
#     'HGNC': 'HGNC:9646',
#     'end': 86815171,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'RICTOR',
#     'level': 'manually annotated loci',
#     'displayName': 'RICTOR',
#     'start': 38937920,
#     'source': 'HAVANA',
#     'chr': '5',
#     'uuid': 'ENSG00000164327',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000164327.14',
#     'HGNC': 'HGNC:28611',
#     'end': 39074402,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'RTEL1',
#     'level': 'verified loci',
#     'displayName': 'RTEL1',
#     'start': 63657810,
#     'source': 'HAVANA',
#     'chr': '20',
#     'uuid': 'ENSG00000258366',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000258366.12',
#     'HGNC': 'HGNC:15888',
#     'end': 63696253,
#     'tag': ['overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SDHC',
#     'level': 'manually annotated loci',
#     'displayName': 'SDHC',
#     'start': 161314381,
#     'source': 'HAVANA',
#     'chr': '1',
#     'uuid': 'ENSG00000143252',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000143252.16',
#     'HGNC': 'HGNC:10682',
#     'end': 161363206,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SETD2',
#     'level': 'manually annotated loci',
#     'displayName': 'SETD2',
#     'start': 47016428,
#     'source': 'HAVANA',
#     'chr': '3',
#     'uuid': 'ENSG00000181555',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000181555.22',
#     'HGNC': 'HGNC:18420',
#     'end': 47164113,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SETDB1',
#     'level': 'verified loci',
#     'displayName': 'SETDB1',
#     'start': 150926263,
#     'source': 'HAVANA',
#     'chr': '1',
#     'uuid': 'ENSG00000143379',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000143379.13',
#     'HGNC': 'HGNC:10761',
#     'end': 150964744,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SLC3A2',
#     'level': 'verified loci',
#     'displayName': 'SLC3A2',
#     'start': 62856004,
#     'source': 'HAVANA',
#     'chr': '11',
#     'uuid': 'ENSG00000168003',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000168003.19',
#     'HGNC': 'HGNC:11026',
#     'end': 62888880,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'SOX9',
#     'level': 'manually annotated loci',
#     'displayName': 'SOX9',
#     'start': 72121020,
#     'source': 'HAVANA',
#     'chr': '17',
#     'uuid': 'ENSG00000125398',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000125398.8',
#     'HGNC': 'HGNC:11204',
#     'end': 72126416,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'STIM1',
#     'level': 'verified loci',
#     'displayName': 'STIM1',
#     'start': 3854527,
#     'source': 'HAVANA',
#     'chr': '11',
#     'uuid': 'ENSG00000167323',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000167323.13',
#     'HGNC': 'HGNC:11386',
#     'end': 4093210,
#     'tag': ['ncRNA_host', 'overlapping_locus']},
#    {'biotype': 'protein_coding',
#     'symbol': 'TNFRSF1A',
#     'level': 'verified loci',
#     'displayName': 'TNFRSF1A',
#     'start': 6328757,
#     'source': 'HAVANA',
#     'chr': '12',
#     'uuid': 'ENSG00000067182',
#     'strand': -1,
#     'ensembl_gene_id_version': 'ENSG00000067182.9',
#     'HGNC': 'HGNC:11916',
#     'end': 6342114,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'IL13',
#     'level': 'manually annotated loci',
#     'displayName': 'IL13',
#     'start': 132656263,
#     'source': 'HAVANA',
#     'chr': '5',
#     'uuid': 'ENSG00000169194',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000169194.10',
#     'HGNC': 'HGNC:5973',
#     'end': 132661110,
#     'tag': ['']},
#    {'biotype': 'protein_coding',
#     'symbol': 'TLR2',
#     'level': 'manually annotated loci',
#     'displayName': 'TLR2',
#     'start': 153684070,
#     'source': 'HAVANA',
#     'chr': '4',
#     'uuid': 'ENSG00000137462',
#     'strand': 1,
#     'ensembl_gene_id_version': 'ENSG00000137462.9',
#     'HGNC': 'HGNC:11848',
#     'end': 153706260,
#     'tag': ['']}]}]

# %%
[1, 2] + [3,4]
# Out:
# [1, 2, 3, 4]
