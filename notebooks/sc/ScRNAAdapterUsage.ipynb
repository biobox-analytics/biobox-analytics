# %% [markdown]
# ## Single Cell RNA Seq processing: Using CZ Data as the example

# %% [markdown]
# #### The only package that you need to install in order to process single cell rnaseq data from an h5ad file is the biobox-analytics package. The package should install and import the necessary packages, which include: json, os, gzip, math, datetime, itertools, scanpy, pandas

# %%
from biobox_analytics.data.adapters.scrna import ScRNA

# %% [markdown]
# #### Pass in the path to your h5ad file. The object of instance ScRNA will load the object using the scanpy.read_h5ad function. Your h5ad object (scanpy object) is then held under the .rna variable

# %%
scrna = ScRNA(h5adFile="/Users/hamza/Documents/BX/TestData/SingleCell/cz/scRna-0206ea52-4932-4c71-87ed-58d00ffffd49.h5ad")

# %% [markdown]
# #### You can inspect your object freely. However, the major properties that are expected are the obs, holding metadata regarding each cell, and var, holding information about the features being observed (ie the genes) You can should inspect the columns of the obs dataframe to determine what metadata you'd like to capture for the SingleCellExperiment and Donor nodes respectively. It is expected to have a column within the obs dataframe that contains information for mappign each cell to a celltype, encoded using CellType ontology IDs

# %%
scrna.rna.obs
# Out:
#                       donor_id self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGTGTTAGA-1   control_1                           HANCESTRO:0005
# AAACCTGCAAGCGCTC-1   control_1                           HANCESTRO:0005
# AAACCTGCACCAGATT-1   control_1                           HANCESTRO:0005
# AAACCTGCAGTCAGAG-1   control_1                           HANCESTRO:0005
# AAACCTGCATGGAATA-1   control_1                           HANCESTRO:0005
# ...                        ...                                      ...
# TTTGTTGAGACATGCG-11  healthy_6                                  unknown
# TTTGTTGAGGCTTAGG-11  healthy_6                                  unknown
# TTTGTTGCAATCTGCA-11  healthy_6                                  unknown
# TTTGTTGGTACGTGTT-11  healthy_6                                  unknown
# TTTGTTGGTCGAGCTC-11  healthy_6                                  unknown
#
#                     organism_ontology_term_id  \
# AAACCTGAGTGTTAGA-1             NCBITaxon:9606
# AAACCTGCAAGCGCTC-1             NCBITaxon:9606
# AAACCTGCACCAGATT-1             NCBITaxon:9606
# AAACCTGCAGTCAGAG-1             NCBITaxon:9606
# AAACCTGCATGGAATA-1             NCBITaxon:9606
# ...                                       ...
# TTTGTTGAGACATGCG-11            NCBITaxon:9606
# TTTGTTGAGGCTTAGG-11            NCBITaxon:9606
# TTTGTTGCAATCTGCA-11            NCBITaxon:9606
# TTTGTTGGTACGTGTT-11            NCBITaxon:9606
# TTTGTTGGTCGAGCTC-11            NCBITaxon:9606
#
#                                               sample_uuid  \
# AAACCTGAGTGTTAGA-1   d8b737fb-8a38-4a1d-a421-cbc81edddd05
# AAACCTGCAAGCGCTC-1   d8b737fb-8a38-4a1d-a421-cbc81edddd05
# AAACCTGCACCAGATT-1   d8b737fb-8a38-4a1d-a421-cbc81edddd05
# AAACCTGCAGTCAGAG-1   d8b737fb-8a38-4a1d-a421-cbc81edddd05
# AAACCTGCATGGAATA-1   d8b737fb-8a38-4a1d-a421-cbc81edddd05
# ...                                                   ...
# TTTGTTGAGACATGCG-11  8949b21f-6f57-40c0-8f7b-0d6e9bff05cd
# TTTGTTGAGGCTTAGG-11  8949b21f-6f57-40c0-8f7b-0d6e9bff05cd
# TTTGTTGCAATCTGCA-11  8949b21f-6f57-40c0-8f7b-0d6e9bff05cd
# TTTGTTGGTACGTGTT-11  8949b21f-6f57-40c0-8f7b-0d6e9bff05cd
# TTTGTTGGTCGAGCTC-11  8949b21f-6f57-40c0-8f7b-0d6e9bff05cd
#
#                     sample_preservation_method tissue_ontology_term_id  \
# AAACCTGAGTGTTAGA-1              flash-freezing          UBERON:0001225
# AAACCTGCAAGCGCTC-1              flash-freezing          UBERON:0001225
# AAACCTGCACCAGATT-1              flash-freezing          UBERON:0001225
# AAACCTGCAGTCAGAG-1              flash-freezing          UBERON:0001225
# AAACCTGCATGGAATA-1              flash-freezing          UBERON:0001225
# ...                                        ...                     ...
# TTTGTTGAGACATGCG-11             flash-freezing          UBERON:0001225
# TTTGTTGAGGCTTAGG-11             flash-freezing          UBERON:0001225
# TTTGTTGCAATCTGCA-11             flash-freezing          UBERON:0001225
# TTTGTTGGTACGTGTT-11             flash-freezing          UBERON:0001225
# TTTGTTGGTCGAGCTC-11             flash-freezing          UBERON:0001225
#
#                     development_stage_ontology_term_id  \
# AAACCTGAGTGTTAGA-1                      HsapDv:0000148
# AAACCTGCAAGCGCTC-1                      HsapDv:0000148
# AAACCTGCACCAGATT-1                      HsapDv:0000148
# AAACCTGCAGTCAGAG-1                      HsapDv:0000148
# AAACCTGCATGGAATA-1                      HsapDv:0000148
# ...                                                ...
# TTTGTTGAGACATGCG-11                     HsapDv:0000153
# TTTGTTGAGGCTTAGG-11                     HsapDv:0000153
# TTTGTTGCAATCTGCA-11                     HsapDv:0000153
# TTTGTTGGTACGTGTT-11                     HsapDv:0000153
# TTTGTTGGTCGAGCTC-11                     HsapDv:0000153
#
#                                           suspension_uuid suspension_type  \
# AAACCTGAGTGTTAGA-1   a0d05ece-11da-451c-8178-bc66d038afa6         nucleus
# AAACCTGCAAGCGCTC-1   a0d05ece-11da-451c-8178-bc66d038afa6         nucleus
# AAACCTGCACCAGATT-1   a0d05ece-11da-451c-8178-bc66d038afa6         nucleus
# AAACCTGCAGTCAGAG-1   a0d05ece-11da-451c-8178-bc66d038afa6         nucleus
# AAACCTGCATGGAATA-1   a0d05ece-11da-451c-8178-bc66d038afa6         nucleus
# ...                                                   ...             ...
# TTTGTTGAGACATGCG-11  02dbb079-1fdd-4811-81de-9ba8b6962916         nucleus
# TTTGTTGAGGCTTAGG-11  02dbb079-1fdd-4811-81de-9ba8b6962916         nucleus
# TTTGTTGCAATCTGCA-11  02dbb079-1fdd-4811-81de-9ba8b6962916         nucleus
# TTTGTTGGTACGTGTT-11  02dbb079-1fdd-4811-81de-9ba8b6962916         nucleus
# TTTGTTGGTCGAGCTC-11  02dbb079-1fdd-4811-81de-9ba8b6962916         nucleus
#
#                                              library_uuid  ... tissue_type  \
# AAACCTGAGTGTTAGA-1   cccd2996-0f80-4b49-b210-86a55b800dd1  ...      tissue
# AAACCTGCAAGCGCTC-1   cccd2996-0f80-4b49-b210-86a55b800dd1  ...      tissue
# AAACCTGCACCAGATT-1   cccd2996-0f80-4b49-b210-86a55b800dd1  ...      tissue
# AAACCTGCAGTCAGAG-1   cccd2996-0f80-4b49-b210-86a55b800dd1  ...      tissue
# AAACCTGCATGGAATA-1   cccd2996-0f80-4b49-b210-86a55b800dd1  ...      tissue
# ...                                                   ...  ...         ...
# TTTGTTGAGACATGCG-11  84cce7e6-e630-498a-b4a9-3664b6cde8ad  ...      tissue
# TTTGTTGAGGCTTAGG-11  84cce7e6-e630-498a-b4a9-3664b6cde8ad  ...      tissue
# TTTGTTGCAATCTGCA-11  84cce7e6-e630-498a-b4a9-3664b6cde8ad  ...      tissue
# TTTGTTGGTACGTGTT-11  84cce7e6-e630-498a-b4a9-3664b6cde8ad  ...      tissue
# TTTGTTGGTCGAGCTC-11  84cce7e6-e630-498a-b4a9-3664b6cde8ad  ...      tissue
#
#                                                              cell_type  \
# AAACCTGAGTGTTAGA-1                  epithelial cell of proximal tubule
# AAACCTGCAAGCGCTC-1   kidney loop of Henle thick ascending limb epit...
# AAACCTGCACCAGATT-1   kidney loop of Henle thick ascending limb epit...
# AAACCTGCAGTCAGAG-1                  epithelial cell of proximal tubule
# AAACCTGCATGGAATA-1     kidney distal convoluted tubule epithelial cell
# ...                                                                ...
# TTTGTTGAGACATGCG-11                 epithelial cell of proximal tubule
# TTTGTTGAGGCTTAGG-11                 epithelial cell of proximal tubule
# TTTGTTGCAATCTGCA-11  kidney loop of Henle thick ascending limb epit...
# TTTGTTGGTACGTGTT-11                 epithelial cell of proximal tubule
# TTTGTTGGTCGAGCTC-11                 epithelial cell of proximal tubule
#
#                          assay disease      organism     sex  \
# AAACCTGAGTGTTAGA-1   10x 5' v1  normal  Homo sapiens    male
# AAACCTGCAAGCGCTC-1   10x 5' v1  normal  Homo sapiens    male
# AAACCTGCACCAGATT-1   10x 5' v1  normal  Homo sapiens    male
# AAACCTGCAGTCAGAG-1   10x 5' v1  normal  Homo sapiens    male
# AAACCTGCATGGAATA-1   10x 5' v1  normal  Homo sapiens    male
# ...                        ...     ...           ...     ...
# TTTGTTGAGACATGCG-11  10x 3' v3  normal  Homo sapiens  female
# TTTGTTGAGGCTTAGG-11  10x 3' v3  normal  Homo sapiens  female
# TTTGTTGCAATCTGCA-11  10x 3' v3  normal  Homo sapiens  female
# TTTGTTGGTACGTGTT-11  10x 3' v3  normal  Homo sapiens  female
# TTTGTTGGTCGAGCTC-11  10x 3' v3  normal  Homo sapiens  female
#
#                                tissue self_reported_ethnicity  \
# AAACCTGAGTGTTAGA-1   cortex of kidney                European
# AAACCTGCAAGCGCTC-1   cortex of kidney                European
# AAACCTGCACCAGATT-1   cortex of kidney                European
# AAACCTGCAGTCAGAG-1   cortex of kidney                European
# AAACCTGCATGGAATA-1   cortex of kidney                European
# ...                               ...                     ...
# TTTGTTGAGACATGCG-11  cortex of kidney                 unknown
# TTTGTTGAGGCTTAGG-11  cortex of kidney                 unknown
# TTTGTTGCAATCTGCA-11  cortex of kidney                 unknown
# TTTGTTGGTACGTGTT-11  cortex of kidney                 unknown
# TTTGTTGGTCGAGCTC-11  cortex of kidney                 unknown
#
#                            development_stage  observation_joinid
# AAACCTGAGTGTTAGA-1   54-year-old human stage          7R8xa1|~-!
# AAACCTGCAAGCGCTC-1   54-year-old human stage          3Pc4Dv65rX
# AAACCTGCACCAGATT-1   54-year-old human stage          F>nB>Hpgo?
# AAACCTGCAGTCAGAG-1   54-year-old human stage          +UUZ45nZm-
# AAACCTGCATGGAATA-1   54-year-old human stage          4U;((Btbm%
# ...                                      ...                 ...
# TTTGTTGAGACATGCG-11  59-year-old human stage          q%afF8ua<f
# TTTGTTGAGGCTTAGG-11  59-year-old human stage          vqGfC+&&-2
# TTTGTTGCAATCTGCA-11  59-year-old human stage          NCd`koy0En
# TTTGTTGGTACGTGTT-11  59-year-old human stage          ^8Z$aU^A%q
# TTTGTTGGTCGAGCTC-11  59-year-old human stage          Ph(ATeNhf(
#
# [39176 rows x 37 columns]

# %%
scrna.rna
# Out:
# AnnData object with n_obs × n_vars = 39176 × 36398
#     obs: 'donor_id', 'self_reported_ethnicity_ontology_term_id', 'organism_ontology_term_id', 'sample_uuid', 'sample_preservation_method', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'suspension_uuid', 'suspension_type', 'library_uuid', 'assay_ontology_term_id', 'mapped_reference_annotation', 'is_primary_data', 'cell_type_ontology_term_id', 'author_cell_type', 'disease_ontology_term_id', 'reported_diseases', 'sex_ontology_term_id', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'percent.rpl', 'percent.rps', 'doublet_id', 'nCount_SCT', 'nFeature_SCT', 'seurat_clusters', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length'
#     uns: 'citation', 'default_embedding', 'schema_reference', 'schema_version', 'title'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'

# %% [markdown]
# #### Now that you've observed all the necessary columns and have a better understanding of your data, it's time to set the column values. Set the following variables with the appropriate column header values:
# - celltype_col: Column value containing the cell type ontology ID mapping
# - library_col: Column containing the uuid of the single cell rna experiment
# - sample_col: Column containing the uuid of the sample uuid information
# - library_metadata_cols: Array of columns that contain the metadata/information associated with the single cell experiment. Only unique rows per library_col will be kept before transforming each row into an object of type single cell experiment
# - sample_metadata_cols: Array of columns that contain the metadata/information associated with the samples. Only unique rows per sample_col will be kept before transforming each row into an object of type single cell experiment

# %%
celltype_col = 'cell_type_ontology_term_id'
library_col = 'library_uuid'
sample_col = 'sample_uuid'
sample_metadata_cols = ['donor_id', 'sample_uuid', 'self_reported_ethnicity_ontology_term_id', 'sample_preservation_method', 'tissue_ontology_term_id', 'development_stage_ontology_term_id', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage']
library_metadata_cols = ['library_uuid', 'assay', 'tissue_type']

# %% [markdown]
# #### With the variables now set, you can run the iterate_nodes and iterate_edges function to output a node.jsonl.gz and edge.jsonl.gz file respectively. These writes function as appends to the file, so ensure that all previous runs are cleared from the directory before calling the fucntion again. These files will have the correct schema that is ingestible by the BioBox platform. If you would like to hold the nodes and edges in memory, you can set the parameter write_to_disk=False in the function call. Note that because of the extensive number of edge connections between each cell barcode and gene, the edges will not be help in memory

# %%
scrna.iterate_nodes(
    sample_id_col=sample_col,
    sc_library_experiment_id=library_col,
    sample_metadata_cols_to_subset=sample_metadata_cols,
    sc_experiment_cols_to_subset=library_metadata_cols
)
# Out:
# Running function in write mode. Writing to file node.jsonl.gz. To return nodes, set write_to_disk=False in function call
# Create cell nodes
# Writing 39176 cell nodes to file
# Create experiment nodes
# Writing 11 experiment nodes to file
# Create sample nodes
# Writing 11 sample nodes to file
# All nodes written to file: node.jsonl.gz

# %% [markdown]
# #### To prevent excessive memory usage, the cell-gene edges are processed using batches of 1000 cells at a time. These batches are transformed into the correct payload, written to disk, and then cleared from memory before the next batch begins. The print messages will give you updates on which batch is currently being written.

# %%
scrna.iterate_edges(
    sample_id_col=sample_col,
    sc_library_experiment_id=library_col,
    celltype_id_col=celltype_col
)
# Out:
# Running function in write mode. Writing to file edge.jsonl.gz. To return edges, set write_to_disk=False in function call
# Calculating experiment-cell edges
# Writing 39176 experiment-cell edges to file
# Calculating sample-experiment edges
# Writing 11 sample-experiment edges to file
# Calculating cell-celltype edges
# Writing 39176 cell-celltype edges to file
# Calculating cell-gene edges
# Number of cells to process: 39176
# Starting Cell x Gene edge processing now: 2024-06-13 15:25:39.268704
# Processing batch index 0:1000
# Processing batch index 1000:2000
# Processing batch index 2000:3000
# Processing batch index 3000:4000
# Processing batch index 4000:5000
# Processing batch index 5000:6000
# Processing batch index 6000:7000
# Processing batch index 7000:8000
# Processing batch index 8000:9000
# Processing batch index 9000:10000
# Processing batch index 10000:11000
# Processing batch index 11000:12000
# Processing batch index 12000:13000
# Processing batch index 13000:14000
# Processing batch index 14000:15000
# Processing batch index 15000:16000
# Processing batch index 16000:17000
# Processing batch index 17000:18000
# Processing batch index 18000:19000
# Processing batch index 19000:20000
# Processing batch index 20000:21000
# Processing batch index 21000:22000
# Processing batch index 22000:23000
# Processing batch index 23000:24000
# Processing batch index 24000:25000
# Processing batch index 25000:26000
# Processing batch index 26000:27000
# Processing batch index 27000:28000
# Processing batch index 28000:29000
# Processing batch index 29000:30000
# Processing batch index 30000:31000
# Processing batch index 31000:32000
# Processing batch index 32000:33000
# Processing batch index 33000:34000
# Processing batch index 34000:35000
# Processing batch index 35000:36000
# Processing batch index 36000:37000
# Processing batch index 37000:38000
# Processing batch index 38000:39000
# Processing batch index 39000:39176
# Cell x Gene edges written to file: edge.jsonl.gz
# All edges written to file: edge.jsonl.gz

# %% [markdown]
# #### Additionally, to understand the schema of the concepts and relationships of the adapter, you can call the list_schema() function, which will return the metadata associated with this datapack. You can update the name, key, and description of the datapack through the function set_metadata() prior to calling the list_schema() method.

# %%
scrna.list_schema()
# Out:
# {"_meta": {"version": "0.0.1", "date_updated": "2024-06-13 18:26:29.138131"}, "name": "SingleCellRNASeq Datapack - 2024-06-13 18:26:29.138131", "key": "scrna:2024-06-13 18:26:29.138131", "description": "SingleCellRNASeq Datapack created through Python SDK", "dependencies": ["Ensembl"], "concepts": {"SingleCellRNAseqExperiment": {"label": "SingleCellRNAseqExperiment", "dbLabel": "SingleCellRNAseqExperiment", "definition": "Single Cell RNAseq Experiment of the sample tissue"}, "Sample": {"label": "Sample", "dbLabel": "Sample", "definition": "Sample organism from which tissue was taken to be analyzed"}, "CellBarcode": {"label": "CellBarcode", "dbLabel": "CellBarcode", "definition": "Individual cell from scRNA experiment, identified by barcode"}}, "relationships": {"contains cell": {"from": "SingleCellRNAseqExperiment", "to": "CellBarcode"}, "expresses": {"from": "CellBarcode", "to": "Gene"}, "has experiment": {"from": "Sample", "to": "SingleCellRNAseqExperiment"}, "has cell type": {"from": "CellBarcode", "to": "CellType"}}}
# {'_meta': {'version': '0.0.1', 'date_updated': '2024-06-13 18:26:29.138131'},
#  'name': 'SingleCellRNASeq Datapack - 2024-06-13 18:26:29.138131',
#  'key': 'scrna:2024-06-13 18:26:29.138131',
#  'description': 'SingleCellRNASeq Datapack created through Python SDK',
#  'dependencies': ['Ensembl'],
#  'concepts': {'SingleCellRNAseqExperiment': {'label': 'SingleCellRNAseqExperiment',
#    'dbLabel': 'SingleCellRNAseqExperiment',
#    'definition': 'Single Cell RNAseq Experiment of the sample tissue'},
#   'Sample': {'label': 'Sample',
#    'dbLabel': 'Sample',
#    'definition': 'Sample organism from which tissue was taken to be analyzed'},
#   'CellBarcode': {'label': 'CellBarcode',
#    'dbLabel': 'CellBarcode',
#    'definition': 'Individual cell from scRNA experiment, identified by barcode'}},
#  'relationships': {'contains cell': {'from': 'SingleCellRNAseqExperiment',
#    'to': 'CellBarcode'},
#   'expresses': {'from': 'CellBarcode', 'to': 'Gene'},
#   'has experiment': {'from': 'Sample', 'to': 'SingleCellRNAseqExperiment'},
#   'has cell type': {'from': 'CellBarcode', 'to': 'CellType'}}}
